# %% [markdown]
# # Backtest Analysis Template
# Use this notebook to explore backtest results generated by the system.

# %%
from backtesting.runner import StrategyBacktestRunner
from backtesting.engine import BacktestingEngine
from backtesting.combiner import combine_equity_curves
from reports.performance import build_performance_report
from reports.attribution import compute_attribution
import pandas as pd

# price_data = pd.read_csv('data/price_history.csv', parse_dates=['date'], index_col='date')
# strategies = [...]  # Instantiate strategies here
# runner = StrategyBacktestRunner(BacktestingEngine())
# reports = runner.run_strategies(price_data, strategies, position_sizer=lambda s, e: [])
# performance_df = build_performance_report(reports)
# performance_df
